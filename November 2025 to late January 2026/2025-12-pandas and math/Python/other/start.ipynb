# %%
import numpy as np

# %%
my_arr = np.arange(1_000_000)

# %%
my_list = list(range(1_000_000))

# %%
# %timeit my_arr2 = my_arr * 2
# Out:
# 1.71 ms ± 22.3 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit my_list2
